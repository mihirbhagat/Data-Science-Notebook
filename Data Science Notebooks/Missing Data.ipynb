# %% [markdown]
# ## 3 Options for Missing Values

# %% [raw]
# 1. Keep them
# 2. Remove them
# 3. Replace them

# %%
import pandas as pd

df = pd.read_csv('data/vgsales.csv')

# %%
#Checking for missing data

df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# ## Remove Values

# %%
#Drop all rows with missing values 

# dataframe.dropna()

# %%
#Drop columns

#cols_to_remove = ['col1', 'col2']
#cols = [col for col in df.columns if col not in cols_to_remove]
#subset = df[cols]

# %% [markdown]
# ## Replace Values

# %%
#Replace all values with the median

# df['Fare'].fillna(df['Fare'].median())

# %%
# Categoricla data is harder

#df.Pclass.value_counts(normalize=True)

#rel_prob = [.53, .22, .19]
#prob = [i/sum(rel_prob) for i in rel_prob]
#def impute_pclass(value):
    #if value == '?':
        #return np.random.choice(['3','1','2'], p=prob)
    #else:
        #return value
#df.Pclass = df.Pclass.map(lambda x: impute_pclass(x))

# %%
#Values in all columns

for col in df.columns: 
    print('Values for {}:\n{}\n\n'.format(col, df[col].unique()))
# Out:
# Values for Rank:
# [    1     2     3 ... 16598 16599 16600]
#
#
# Values for Name:
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ... 'Plushees'
#  'Woody Woodpecker in Crazy Castle 5' 'Know How 2']
#
#
# Values for Platform:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
#
# Values for Year:
# [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2003. 1986. 2000.   nan 1995. 2016. 1991. 1981. 1987.
#  1980. 1983. 2020. 2017.]
#
#
# Values for Genre:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
#
#
# Values for Publisher:
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
# ...

# %% [markdown]
# ## Keep Values

# %%
#NaN will mess with your models so replace NaN with the string 'NaN' or 'missing'

# %%
#Binning

#Put values in 'bins' and then make an 'unknown bin'

# %% [markdown]
# ## Outliers

# %%
#If normally distributed, outliers are 3 standard deviations from the mean

# %%
#If not normally distributed, outliers are 1.5 x the IQR (interquartile range)

# %% [markdown]
# ## Duplicates

# %%
duplicates = df[df.duplicated()]
print(len(duplicates))
duplicates.head()
# Out:
# 0
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
duplicates = df[df.duplicated(subset='Rank')]
print(len(duplicates))
duplicates.tail()
# Out:
# 0
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []
